# %% [markdown]
# # Python Functions Practice Questions
#
# Predict the output before running each cell.

# %% [markdown]
# ## Q1

# %%
def fun():
    print('Hello')

x=fun()
print(x)

# %% [markdown]
# ## Q2

# %%
def add(a,b):
    return a+b

print(add(5,6))

# %% [markdown]
# ## Q3

# %%
def add(a,b):
    print(a+b)

print(add(5,6))

# %% [markdown]
# ## Q4

# %%
def power(a,b=2):
    return a**b

print(power(3))
print(power(3,3))

# %% [markdown]
# ## Q5

# %%
# Will this compile?
# Why or why not?
# def fun(a=10, b):
#     pass

# %% [markdown]
# ## Q6

# %%
def calc(a,b):
    return a+b, a-b

x=calc(5,2)
print(type(x))
print(x)

# %% [markdown]
# ## Q7

# %%
def calc(a,b):
    return a+b, a-b

x,y=calc(8,5)
print(x)
print(y)

# %% [markdown]
# ## Q8

# %%
def fun(*args):
    print(args)
    print(type(args))

fun(1,2,3,4)

# %% [markdown]
# ## Q9

# %%
def add(*nums):
    s=0
    for x in nums:
        s+=x
    return s

print(add())
print(add(10))
print(add(10,20,30))

# %% [markdown]
# ## Q10

# %%
def info(**kwargs):
    print(kwargs)

info(name='Harsh', age=21)

# %% [markdown]
# ## Q11

# %%
def fun(**x):
    print(x['city'])

fun(name='Harsh', city='Delhi')

# %% [markdown]
# ## Q12

# %%
x=10

def fun():
    x=20
    print(x)

fun()
print(x)

# %% [markdown]
# ## Q13

# %%
x=10

def fun():
    global x
    x=50

fun()
print(x)

# %% [markdown]
# ## Q14

# %%
def outer():
    x=5
    def inner():
        nonlocal x
        x=10
    inner()
    print(x)
outer()

# %% [markdown]
# ## Q15

# %%
def greet():
    print('Hello')

x=greet
x()

# %% [markdown]
# ## Q16

# %%
def greet():
    return 'Hello'

x=greet
print(x())

# %% [markdown]
# ## Q17

# %%
def square(x):
    return x*x

def operate(fun,x):
    return fun(x)

print(operate(square,6))

# %% [markdown]
# ## Q18

# %%
def cube(x):
    return x*x*x

def apply(fun,val):
    return fun(val)

print(apply(cube,3))

# %% [markdown]
# ## Q19

# %%
square=lambda x:x*x
print(square(8))

# %% [markdown]
# ## Q20

# %%
add=lambda a,b:a+b
print(add(10,20))

# %% [markdown]
# ## Q21

# %%
def fun(lst=[]):
    lst.append(1)
    return lst

print(fun())
print(fun())
print(fun())

# Why does this happen?

# %% [markdown]
# ## Q22

# %%
# Fix Q21 so every call returns [1].

# %% [markdown]
# ## Q23

# %%
def fun(a,b=10,*args,**kwargs):
    print(a)
    print(b)
    print(args)
    print(kwargs)

fun(1,2,3,4,x=5,y=6)

# %% [markdown]
# ## Q24

# %%
def fun():
    return

print(fun())

# %% [markdown]
# ## Q25

# %%
def fun():
    pass

print(fun())

# %% [markdown]
# ## Bonus

# %%
def outer():
    x=10
    def inner():
        nonlocal x
        x+=5
        return x
    print(inner())
    print(x)

outer()
