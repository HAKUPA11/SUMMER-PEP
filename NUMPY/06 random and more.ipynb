# %% [markdown]
# matrix, dotproduct, linalg, rng, seed, shuffle, choice in shuffle, difference between uniform and normal distribution

# %% [markdown]
# legacy fxns (older)np.random.randint, np,random.rand(), np.random.choice() , np.random.seed(), np.random.uniform() and many more

# %% [markdown]
# time companrison of list and numpy array by using import time and then using list(range(size)) and then np.arange(size where size is 100000000 )
